# %%
import pandas as pd
import wikipedia
import requests
from bs4 import BeautifulSoup

# %%
link = "https://en.wikipedia.org/wiki/List_of_saints#Christian_saints_since_AD_300"

table=pd.read_html(link,header=0)[0] #Get the first table which is the list of saints
saints = list(table.Saint[1:,]) #Make a list out of saints, drop first, since there is inconsistency on header in pandas

# %%
#url = r'https://en.wikipedia.org/wiki/Category:Roman_Catholic_saints_by_nationality' 
#r = requests.get(url)
#r.text

# %%
saints[:10]
# Out:
# ['Abakuh',
#  'Abamun of Tarnut',
#  'Abaskhayroun',
#  'Abban of Magheranoidhe',
#  'Abban of New Ross',
#  'Abban the Hermit',
#  'Abbo of Fleury',
#  'Abdas of Susa',
#  'Abel of Reims',
#  'Saint Abib']

# %%
#Make URL for the saint
url1 = 'https://en.wikipedia.org/wiki/'
def get_url(saint_name):
    URL = url1+saint_name
    return URLs

# %%
#Find info box for the saint url
def find_box(URL):
    S = requests.Session()
    R = S.get(url=URL)
    wiki = BeautifulSoup(R.text,'html.parser')
    info_box = wiki.find('table',{'class':'infobox vcard'})
    return info_box

# %%
# Find the row with 'Born' information
def born(info_box):
    try:
        for tr in info_box.findAll('tr'):
            for string in tr.strings:
                if string == 'Born':
                    return (tr)
    except:
        pass
# a for a in info_box.findAll('tr') if a == b

# %%
#Make a list of url for saints
url_list=[]
for i in saints:
    url_list.append(get_url(i))

# %%
#Make a list of info_boxes
info_list=[]
for i in url_list:
    info_list.append(find_box(i))

# %%
#Make a list of born sentences from info boxes for Saints
born_list = []
for i in info_list:
    born_list.append(born(i))

# %%
#Make a list of towns where saints were born
towns=[]
def get_towns(list_of_boxes):
    for box in info_list:
        try:
            for string in born(box).find('a').strings:
                        towns.append(string)
        except:
            pass

# %%
len(towns)
# Out:
# 450

# %%
#Export list of towns as a csv
import csv

with open('towns.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(towns)

# %%
towns_df = pd.DataFrame(towns,columns=['town'])
towns_df['size'] = 1

# %%
towns_df.groupby(['town']).count().reset_index()
# Out:
#                        town  size
# 0                        AD     1
# 1                    Abbach     1
# 2                   Alençon     1
# 3                Alexandria     4
# 4         Alexandria, Egypt     5
# 5          Aljafería Palace     1
# 6         Aljustrel, Fátima     2
# 7                   Amettes     1
# 8                   Andechs     1
# 9                   Antioch     1
# 10                    Aosta     1
# 11                 Aquileia     1
# 12                Aquitaine     1
# 13                   Assisi     3
# 14                 Asunción     1
# 15                    Autun     1
# 16                 Auvergne     2
# 17                      Auw     1
# 18                   Avalon     1
# 19               Ayguatébia     1
# 20                 Azpeitia     1
# 21            Bad Griesbach     1
# 22                    Badia     1
# 23                  Baghdad     1
# 24               Bagnoregio     1
# 25           Baltonsborough     1
# 26                Barbastro     1
# 27               Barnstaple     1
# 28             Bastia Umbra     1
# 29                   Beirut     1
# ..                      ...   ...
# 313                 Venetia     1
# 314                  Venice     1
# 315                   Verdú     1
# 316              Vermandois     1
# 317                     Vic     2
# 318                 Vietnam     2
# 319              Vignanello     1
# 320          Vigolo Vattaro     1
# 321  Vilafranca del Penedès     1
# 322       Villa Santa Maria     1
# 323                 Vilnius     1
# 324        Viloria de Rioja     1
# 325                 Viterbo     1
# 326            Viña del Mar     1
# 327               Volodymyr     1
# 328           Västergötland     1
# 329                Wadowice     1
# 330        Walpole, Norfolk     1
# 331              Wilamowice     1
# 332                    York     1
# 333                Zaragoza     1
# 334                     [1]    24
# 335                       c     1
# 336                      c.     8
# 337                      ca     1
# 338                     ca.     1
# 339         citation needed     1
# 340                frazione     1
# 341                   Ávila     1
# 342            Ōmura Domain     1
#
# [343 rows x 2 columns]
